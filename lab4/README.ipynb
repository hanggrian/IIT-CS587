# %% [markdown]
# # [Lab 4](https://github.com/hanggrian/IIT-CS587/blob/assets/assignments/lab4_1.pdf): LlamaIndex Experiments
#
# > After you complete the tasks listed in the instructions document (`Lab_4.zip`), submit (a link in this class discussion where anyone of your classmates will be able to watch) the Panopto Video Recording of a successful run on your computer.
# >
# > - Download and run the provide IPYNB scripts on your computer, submit (a link in this class discussion where anyone of your classmates will be able to watch) the Panopto Video Recording of a successful run on your computer.
# > - Based on the 4 experiments you executed using 3 different models using Ollama and Replicate, provide your answers for the following:
#
# Screen recordings:
#
# - [Ollama](https://github.com/hanggrian/IIT-CS587/raw/assets/lab4/screenrecord1.mp4)
# - [OpenAI](https://github.com/hanggrian/IIT-CS587/raw/assets/lab4/screenrecord2.mp4)
# - [Replicate](https://github.com/hanggrian/IIT-CS587/raw/assets/lab4/screenrecord3.mp4)
#
# ## Requirements
#
# 1.  [x] Install Python version 3.10: [python310<sup>AUR</sup>](https://aur.archlinux.org/packages/python310)
# 1.  [x] Install development environment:
#     - VSCode: [visual-studio-code-bin<sup>AUR</sup>](https://aur.archlinux.org/packages/visual-studio-code-bin)
#     - Jupyter: [jupyterlab](https://archlinux.org/packages/extra/any/jupyterlab)
# 1.  [x] Check Python version.
#     ```sh
#     python --version
#     ```
# 1.  [x] Create a virtual environment and link notebook kernel.
#     ```sh
#     source .venv/bin/activate
#     python -m ipykernel install --user --name=.venv
#     ```
# 1.  [x] Install packages:
#     - `uv` project manager.
#       ```sh
#       pip install uv
#       ```
#     - `pyautogen` and dependencies for lessons.
#       ```
#       uv pip install -r requirements.txt
#       ```
# 1.  [x] Create a Llama Cloud account and API key.
# 1.  [x] Create a Replicate account and API key.
# 1.  [x] Install Ollama: [ollama](https://archlinux.org/packages/extra/x86_64/ollama)
# 1.  [x] Learn LlamaIndex [documentation](https://www.llamaindex.ai/).
# 1.  [x] Verify four models.
# 1.  Complete four experiments.
#     1.  [ ] **Ollama.ipynb** script with model **llama3.2:3b**
#     1.  [x] **OpenAI.ipynb** script with model **gpt-4o-mini**
#     1.  [x] **Replicate.ipynb** script with model **deepseek-ai/deepseek-r1**
#     1.  [x] **Replicate.ipynb** script with model **meta/meta-llama-3-70b-instruct**
#
# ## [Questions](https://github.com/hanggrian/IIT-CS587/blob/assets/assignments/lab4_2.pdf)
#
# > Did you encounter any issue part of the setup process?
#
# Yes, I could not complete the setup process with Ollama. The script demanded 44GB of available memory.
#
# > What was the computer hardware (processor (CPU and GPU) and main memory) that you have on your computer?
#
# - **CPU:** Intel Core i5-10400
# - **RAM:** 32GB DDR4
# - **GPU:** AMD RX580 8GB
#
# > How long did it take you to complete the installation?
#
# It took about 30 minutes to sign up for Replicate account, produce the API key and setup the environment variables.
#
# > How long did it take to complete the execution of the provided/modified IPYNB script for every model?
#
# - **Ollama:** Did not complete due to memory constraints.
# - **OpenAI:** Four minutes to complete the conversation.
# - **Replicate:** There are two models, each taking six to eight minutes.
#
# > Comment on the quality of the output produced for every model.
#
# Three out of four models completed successfully. The OpenAI model produced concise responses, usually few sentences in a paragraph. The DeepSeek model hosted on Replicate has a better print formatting.
#
# > Comment on the speed for every model.
#
# The OpenAI model is the fastest reasoning model. Llama on Replicate ranks second while DeepSeek is the slowest model.
#
# > Which model provided the complete, correct, and coherent responses? Explain your answer.
#
# DeepSeek R1 produced the most complete response. However, it is also the slowest and high level of detail is not always necessary in some tasks.
